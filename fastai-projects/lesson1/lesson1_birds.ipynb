# %%
from fastai.vision.all import *
print("test")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from fastai.vision.all import *
#       2 print("test")
#
# File ~/miniconda3/envs/fastai/lib/python3.9/site-packages/fastai/vision/all.py:1
# ----> 1 from . import models
#       2 from ..basics import *
#       3 from ..callback.all import *
#
# File ~/miniconda3/envs/fastai/lib/python3.9/site-packages/fastai/vision/models/__init__.py:2
#       1 from . import xresnet
# ----> 2 from . import unet
#       3 from .tvm import *
#
# File ~/miniconda3/envs/fastai/lib/python3.9/site-packages/fastai/vision/models/unet.py:8
#       6 from __future__ import annotations
#       7 from ...torch_basics import *
# ----> 8 from ...callback.hook import *
#      10 # %% auto 0
#      11 __all__ = ['UnetBlock', 'ResizeToOrig', 'DynamicUnet']
#
# ...
